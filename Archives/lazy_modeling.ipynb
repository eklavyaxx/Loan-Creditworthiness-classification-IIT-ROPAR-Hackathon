# %% [markdown]
# #### Building a Model using Lazy Predictor to check which model gives better results
#
# Note - It is only for understanding Purpose (I will build my own model)

# %%
from lazypredict.Supervised import LazyClassifier, LazyRegressor
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
data = pd.read_csv('Data/Preprocessed/final.csv')

# %%
X= data[data.columns.drop('high_risk_applicant')]
Y = data['high_risk_applicant']

# %%
train_x, test_x,train_y, test_y = train_test_split(X,Y, shuffle = True, stratify=Y)

# %%
clf = LazyClassifier(predictions=True)

models, predictions = clf.fit(train_x, test_x,train_y, test_y)
# Out:
#  90%|████████▉ | 26/29 [00:03<00:00, 10.63it/s]
# [18:06:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 100%|██████████| 29/29 [00:03<00:00,  7.99it/s]

# %%
models
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# GaussianNB                         0.67               0.64     0.64      0.68
# AdaBoostClassifier                 0.74               0.63     0.63      0.72
# NearestCentroid                    0.65               0.63     0.63      0.66
# SGDClassifier                      0.70               0.61     0.61      0.69
# BernoulliNB                        0.72               0.61     0.61      0.70
# XGBClassifier                      0.71               0.60     0.60      0.69
# LinearDiscriminantAnalysis         0.74               0.60     0.60      0.69
# ExtraTreeClassifier                0.66               0.60     0.60      0.66
# LogisticRegression                 0.74               0.60     0.60      0.69
# RandomForestClassifier             0.74               0.59     0.59      0.69
# BaggingClassifier                  0.72               0.59     0.59      0.68
# NuSVC                              0.71               0.58     0.58      0.68
# LinearSVC                          0.74               0.58     0.58      0.68
# KNeighborsClassifier               0.69               0.58     0.58      0.67
# ExtraTreesClassifier               0.70               0.58     0.58      0.67
# RidgeClassifier                    0.74               0.58     0.58      0.68
# RidgeClassifierCV                  0.74               0.58     0.58      0.68
# CalibratedClassifierCV             0.74               0.58     0.58      0.67
# LGBMClassifier                     0.69               0.58     0.58      0.67
# SVC                                0.73               0.57     0.57      0.67
# Perceptron                         0.67               0.56     0.56      0.65
# DecisionTreeClassifier             0.58               0.54     0.54      0.60
# LabelSpreading                     0.60               0.52     0.52      0.60
# LabelPropagation                   0.60               0.52     0.52      0.60
# PassiveAggressiveClassifier        0.62               0.51     0.51      0.60
# DummyClassifier                    0.70               0.50     0.50      0.58
# QuadraticDiscriminantAnalysis      0.30               0.48     0.48      0.18
#
#                                Time Taken
# Model
# GaussianNB                           0.03
# AdaBoostClassifier                   0.27
# NearestCentroid                      0.02
# SGDClassifier                        0.04
# BernoulliNB                          0.03
# XGBClassifier                        0.40
# LinearDiscriminantAnalysis           0.04
# ExtraTreeClassifier                  0.03
# LogisticRegression                   0.05
# RandomForestClassifier               0.53
# BaggingClassifier                    0.11
# NuSVC                                0.11
# LinearSVC                            0.14
# KNeighborsClassifier                 0.05
# ExtraTreesClassifier                 0.54
# RidgeClassifier                      0.03
# RidgeClassifierCV                    0.03
# CalibratedClassifierCV               0.47
# LGBMClassifier                       0.20
# SVC                                  0.11
# Perceptron                           0.02
# DecisionTreeClassifier               0.04
# LabelSpreading                       0.12
# LabelPropagation                     0.12
# PassiveAggressiveClassifier          0.03
# DummyClassifier                      0.02
# QuadraticDiscriminantAnalysis        0.03
